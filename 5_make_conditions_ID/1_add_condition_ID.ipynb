# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from os import path
from pathlib import Path

# %%
data_file = path.join('/home/amy/Documents/GitHub/modulome-C_Glutamicum_Microarray_clean/5_make_conditions_ID/net_data_swapped.xlsx') # Enter metadata filename here
data = pd.read_excel(data_file,index_col=0).fillna("NaN")

# %%
titles = data['Sample name'].tolist()
platform =  data['Platform'].tolist()
source = data['Label strain'].tolist()
for i in range(len(titles)):
    titles[i] = titles[i].replace("-rep1","")
    titles[i] = titles[i].replace("-rep2","")
    titles[i] = titles[i].replace("-rep3","")
    titles[i] = titles[i].replace("-rep4","")
    titles[i] = titles[i].replace("-rep5","")
    titles[i] = titles[i].replace("-rep6","")
    titles[i] = titles[i].replace("-rep7","")
    titles[i] = titles[i].replace("-rep8","")
    if titles[i][0].isdigit():
        temp = titles[i].index('_')
        titles[i] = titles[i][(temp+1):]
#ds_conditions['Title'] = titles
titles_set = list(set(titles))

# %%
Experiment_ID = []
for i in range(len(titles)):
    temp = "Experiment"+str(titles_set.index(titles[i]))
    if source[i] == "Cy5":
        temp = temp + "_Source1"
    else:
        temp = temp + "_Source2"
    if platform[i] == "Agilent":
        temp = temp + "_Agilent"
    else:
        temp = temp+ "_Operon"
    Experiment_ID.append(temp)

# %%
conditions_set = list(set(Experiment_ID))
conditions_ID = []
for i in range(len(titles)):
    temp = "Condition"+str(conditions_set.index(Experiment_ID[i]))
    conditions_ID.append(temp)

# %%
data["Experiment ID"] = Experiment_ID
data["condition"] = conditions_ID
data.drop(['Platform','Mean/Median','Fluorescence','Label strain'], axis = 1)
# Out:
#                                                   Sample name     cg0001  \
# Sample ID
# GSM5197852  ∆6C (0.75 µM mitomycin C) vs. WT (0.75 µM mito...   404.6870
# GSM5197852  ∆6C (0.75 µM mitomycin C) vs. WT (0.75 µM mito...  2507.0440
# GSM5197853  ∆6C (0.75 µM mitomycin C) vs. WT (0.75 µM mito...  -686.0000
# GSM5197853  ∆6C (0.75 µM mitomycin C) vs. WT (0.75 µM mito...  1707.0000
# GSM5197854  ∆6C (0.75 µM mitomycin C) vs. WT (0.75 µM mito...   -88.0000
# ...                                                       ...        ...
# GSM5197805    ∆cgtSR5 (20 µM CuSO4) vs. WT (20 µM CuSO4)-rep3  1197.6390
# GSM5197808  ∆cgtSR5 (w/o CuSO4, OD 20) vs. ∆cgtSR5 (OD 20)...  1343.5374
# GSM5197808  ∆cgtSR5 (w/o CuSO4, OD 20) vs. ∆cgtSR5 (OD 20)...  2094.7730
# GSM5197811  ∆cgtSR5 (w/o CuSO4, OD 20) vs. ∆cgtSR5 (OD 20)...   649.3158
# GSM5197811  ∆cgtSR5 (w/o CuSO4, OD 20) vs. ∆cgtSR5 (OD 20)...  1356.1908
#
#               cg0002      cg0004     cg0005  cg0006     cg0007     cg0008  \
# Sample ID
# GSM5197852    0.0000   2932.1040   333.0000    79.0  1345.9640     0.0000
# GSM5197852    0.0000   7801.1390  1978.0000  1849.0  6165.9780     0.0000
# GSM5197853    0.0000   1997.0000     0.0000     0.0  1100.0000     0.0000
# GSM5197853    0.0000   4148.4400     0.0000     0.0  4234.0000     0.0000
# GSM5197854    0.0000   1793.6540   291.0000   269.0  1137.7310   207.0000
# ...              ...         ...        ...     ...        ...        ...
# GSM5197805    0.0000   5389.3990     0.0000     0.0  3395.5070     0.0000
# GSM5197808  646.9766   7949.5912   704.2830   327.0  4904.1910   844.1129
# GSM5197808  781.4550   9571.6150   908.7070   535.0  5293.2850  1066.9450
# GSM5197811    0.0000   7000.7830   488.9618   147.0  3769.0212   318.6912
# GSM5197811    0.0000  10042.5255   750.9442   290.0  6742.2222   433.7767
#
#                cg0009      cg0010  ...  cg4001  cg4002     cg4003     cg4004  \
# Sample ID                          ...
# GSM5197852   168.0000   1588.5970  ...     0.0     0.0     0.0000     0.0000
# GSM5197852   876.0000   7753.0340  ...     0.0     0.0     0.0000     0.0000
# GSM5197853     0.0000   3157.8800  ...     0.0     0.0     0.0000     0.0000
# GSM5197853     0.0000   9352.9260  ...     0.0     0.0     0.0000     0.0000
# GSM5197854     8.0000   1076.0260  ...     0.0     0.0     0.0000     0.0000
# ...               ...         ...  ...     ...     ...        ...        ...
# GSM5197805   607.0000  12923.3510  ...     0.0     0.0     0.0000   523.0000
# GSM5197808  1307.9650  12120.5469  ...     0.0   226.0   734.7655  1018.9429
# GSM5197808  1287.1813  13895.9013  ...     0.0   579.0  1007.5413   961.2670
# GSM5197811   491.8592  10328.4818  ...     0.0     0.0     0.0000   578.7090
# GSM5197811   901.3683  12136.7000  ...     0.0     0.0     0.0000   860.3153
#
#                 cg4005     cg4006     cg4007  Sample ID.1  \
# Sample ID
# GSM5197852   2334.5650     0.0000   592.0000   GSM5197852
# GSM5197852  13018.5350     0.0000   919.0000   GSM5197852
# GSM5197853   1123.5400     0.0000     0.0000   GSM5197853
# GSM5197853   7716.1790     0.0000     0.0000   GSM5197853
# GSM5197854   1434.8750     0.0000   366.0000   GSM5197854
# ...                ...        ...        ...          ...
# GSM5197805   7604.7120   787.0010   607.8490   GSM5197805
# GSM5197808  24769.5622  1297.4789  3241.4729   GSM5197808
# GSM5197808  30708.6350  1705.4410  4164.0370   GSM5197808
# GSM5197811  10213.3054   943.8410   717.4194   GSM5197811
# GSM5197811  23455.3177  1199.1074  2384.2461   GSM5197811
#
#                             Experiment ID     condition
# Sample ID
# GSM5197852  Experiment257_Source1_Agilent  Condition326
# GSM5197852  Experiment257_Source2_Agilent  Condition536
# GSM5197853  Experiment257_Source1_Agilent  Condition326
# GSM5197853  Experiment257_Source2_Agilent  Condition536
# GSM5197854  Experiment257_Source1_Agilent  Condition326
# ...                                   ...           ...
# GSM5197805   Experiment102_Source1_Operon  Condition516
# GSM5197808   Experiment176_Source2_Operon  Condition473
# GSM5197808   Experiment176_Source1_Operon  Condition446
# GSM5197811   Experiment176_Source2_Operon  Condition473
# GSM5197811   Experiment176_Source1_Operon  Condition446
#
# [1608 rows x 3051 columns]

# %%
filepath = Path('/home/amy/Documents/GitHub/modulome-C_Glutamicum_Microarray_clean/5_make_conditions_ID/1_data_condition_ID.xlsx')
filepath.parent.mkdir(parents=True, exist_ok=True)  
data.to_excel(filepath)
